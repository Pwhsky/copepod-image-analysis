# %%
import deeptrack as dt
import numpy as np
from matplotlib import pyplot as plt

img = dt.LoadImage("copepod_images/IMG_6940.png")
img= np.array(img.resolve())

ys    = [1263]
xs    = [2405]

training_images = []
number_of_crops = len(ys)

for i in range(number_of_crops):
    #go through the positions for the crops
    y_index   = ys[i]
    x_index   = xs[i]
    crop_size = 48
    x0,y0 = y_index-crop_size // 2, x_index - crop_size//2
    training_image = np.array(   img[x0:x0+crop_size, y0: y0 + crop_size])
    #training_image = cv2.cvtColor(training_image,cv2.COLOR_BGR2GRAY)
    #training_image = np.expand_dims(training_image,axis=-1)
    training_images.append(training_image)
    plt.subplot(1,number_of_crops,i+1)
    plt.axis("off")
    plt.imshow(training_image,cmap="gray")
np.shape(training_image)
# Out:
# (48, 48, 3)

# %% [markdown]
# # Data from IMG_6953.png

# %%
img = dt.LoadImage("copepod_images/IMG_6953.png")
img = np.array(img.resolve())

#Some single copepod positions from cope_1.png, additional crops are commented out.
ys    = [2480,1597,1295,1279,1225]
xs    = [1509,1715,1690,1647, 1047]

number_of_crops = len(ys)

for i in range(number_of_crops):
    #go through the positions for the crops
    y_index   = ys[i]
    x_index   = xs[i]
    crop_size = 48
    x0,y0 = y_index-crop_size // 2, x_index - crop_size//2
    training_image = np.array(   img[x0:x0+crop_size, y0: y0 + crop_size])
    training_images.append(training_image)
    plt.subplot(1,number_of_crops,i+1)
    plt.axis("off")
    plt.imshow(training_image,cmap="gray")
np.shape(training_image)
# Out:
# [ WARN:0@1.370] global loadsave.cpp:248 findDecoder imread_('copepod_images/cope_4.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 img = dt.LoadImage("copepod_images/cope_4.png")
# ----> 2 img = np.array(img.resolve())
#       4 #Some single copepod positions from cope_1.png, additional crops are commented out.
#       5 ys    = [2480,1597,1295,1279,1225]
#
# File ~/.local/lib/python3.10/site-packages/deeptrack/features.py:192, in Feature.__call__(self, image_list, _ID, **kwargs)
#     189             self.arguments.properties[key].set_value(value, _ID=_ID)
#     191 # This executes the feature. DeepTrackNode will determine if it needs to be recalculated. If it does, it will call the `action` method.
# --> 192 output = super(Feature, self).__call__(_ID=_ID)
#     194 # If we have self.arguments, we reset the values of self.arguments to their original values.
#     195 for key, value in original_values.items():
#
# File ~/.local/lib/python3.10/site-packages/deeptrack/backend/core.py:307, in DeepTrackNode.__call__(self, _ID)
#     304         pass
#     306 if self._accepts_ID:
# --> 307     new_value = self.action(_ID=_ID)
#     308 else:
#     309     new_value = self.action()
#
# File ~/.local/lib/python3.10/site-packages/deeptrack/features.py:315, in Feature.action(self, _ID)
#     308 image_list = self._format_input(image_list, **feature_input)
#     310 # Set the seed from the hash_key. Ensures equal results
#     311 # self.seed(_ID=_ID)
#     312
#     313 # _process_and_get calls the get function correctly according
#     314 # to the __distributed__ attribute
# --> 315 new_list = self._process_and_get(image_list, **feature_input)
#     317 self._process_output(new_list, feature_input)
#     320 # Merge input and new_list
#
# File ~/.local/lib/python3.10/site-packages/deeptrack/features.py:683, in Feature._no_wrap_process_and_get(self, image_list, **feature_input)
#     679     return [self.get(x, **feature_input) for x in image_list]
#     681 else:
#     682     # Call get on entire list.
# --> 683     new_list = self.get(image_list, **feature_input)
#     685     if not isinstance(new_list, list):
#     686         new_list = [new_list]
#
# File ~/.local/lib/python3.10/site-packages/deeptrack/features.py:1683, in LoadImage.get(self, path, load_options, ndim, to_grayscale, as_list, get_one_random, *ign, **kwargs)
#    1679         import warnings
#    1681         warnings.warn("Non-rgb image, ignoring to_grayscale")
# -> 1683 while ndim and image.ndim < ndim:
#    1684     image = np.expand_dims(image, axis=-1)
#    1686 return image
#
# AttributeError: 'NoneType' object has no attribute 'ndim'

# %% [markdown]
# # Data from IMG_6949.png

# %%
img = dt.LoadImage("copepod_images/IMG_6940.png")
img = np.array(img.resolve()) 

ys    = [2145,2307,2040]
xs    = [1199,1423,1610]

number_of_crops = len(ys)
for i in range(number_of_crops):
    #go through the positions for the crops
    y_index   = ys[i]
    x_index   =  xs[i]
    crop_size = 48
    x0,y0 = y_index-crop_size // 2, x_index - crop_size//2
    training_image = np.array(   img[x0:x0+crop_size, y0: y0 + crop_size])
    training_images.append(training_image)
    plt.subplot(1,number_of_crops,i+1)
    plt.axis("off")
    plt.imshow(training_image,cmap="gray")
np.shape(training_image)
# Out:
# (48, 48, 3)

# %%
image = dt.LoadImage("copepod_images/IMG_6940.png")
image = np.array(image.resolve()) 

crop_size =48
y_index = 1263
x_index = 2405
x0,y0 = y_index-crop_size // 2, x_index - crop_size//2
training_image = np.array(   image[x0:x0+crop_size, y0: y0 + crop_size])
plt.imshow(training_image)

# %% [markdown]
# # Save training_image list to a file

# %%
num_images = len(training_images)
fig, axs = plt.subplots(1, num_images, figsize=(15, 5))
for image in training_images:
    image = dt.FlipLR(1)
    
for i, image in enumerate(training_images):
    axs[i].imshow(image, cmap='gray')
    axs[i].axis('off')
np.savez('test_data.npz',*training_images)
print(f"Length of training data: {num_images}")
# Out:
# Length of training data: 25
